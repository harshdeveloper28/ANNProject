# %% [markdown]
# Determining the optimal number of hidden layersand neurons for an ANN

# %%
import pandas as pd
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler,OneHotEncoder,LabelEncoder
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasClassifier
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
import pickle

# %%
# paste the same code from reading the csv file to preprocess and saving the file in pkl format

# %%
# Define a function to create the model and try different parameters (kerasClassifier)
def create_model(neurons=32,layers=1):
    model=Sequential()
    model.add(Dense(neurons,activation='relu',input_shape=(X_train.shape[1],)))

    for _ in range(layers-1):
        model.add(Dense(neurons,activation='relu'))
    
    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

    return model

# %%
# create a keras classifier 
model=KerasClassifier(build_fn=create_model,epochs=50,batch_size=10,verbose=0)

# %%
# param_grid
param_grid={
    'neurons':[16,32,64,128],
    'layers':[1,2],
    'epochs':[50,100]
}

# %%
# Perform Grid Search 
grid = GridSearchCV(estimator=model,param_grid=param_grid,n_jobs=1, cv=3)
grid_result= grid.fit(X_train,y_train)

# print the best parameters
print(f"Best: %f using %s" % ( grid_result.best_score_,grid_result.best_params_))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Perform Grid Search
# ----> 2 grid = GridSearchCV(estimator=model,param_grid=param_grid,n_jobs=1, cv=3)
#       3 grid_result= grid.fit(X_train,y_train)
#       5 # print the best parameters
#
# NameError: name 'model' is not defined
